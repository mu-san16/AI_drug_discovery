# %%
import pandas as pd
import numpy as np

# %%
file_path = '/Users/yutonakamura/AI_drug_discovery/data/BindingDB_All_202311 2.tsv'
df = pd.read_csv(file_path, sep='\t', nrows=200)
df
# Out:
#      BindingDB Reactant_set_id  \
# 0                            1
# 1                            2
# 2                            3
# 3                            4
# 4                            5
# ..                         ...
# 195                        196
# 196                        197
# 197                        198
# 198                        199
# 199                        200
#
#                                          Ligand SMILES  \
# 0    O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CCCCCC(O)=...
# 1    O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(C\C=C\c2cn...
# 2    O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CC2CC2)C(=...
# 3    OCCCCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@...
# 4    OCCCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@H...
# ..                                                 ...
# 195  CC(C)CN(C[C@H](O)[C@H](Cc1ccccc1)NC(=O)[C@H](C...
# 196  COc1ccc(CN(C[C@H](O)[C@H](Cc2ccccc2)NC(=O)[C@H...
# 197  CCOC(=O)N[C@@H](C(C)C)C(=O)NN(C[C@H](O)[C@H](C...
# ...

# %% [markdown]
# データの取得まではできている
# 必要なデータを取り出し、データを加工する作業に移る
